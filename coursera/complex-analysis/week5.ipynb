# %%
import numpy as np 
import matplotlib.pyplot as plt 
from collections import deque
from PIL import Image

# %%
fig = plt.figure(figsize=(20,40))
ax =fig.add_subplot(1,2,1)
ax.set_title("a")
ax.axis("off")
plt.imshow(Image.open("./week5-problem1-img.png"))
plt.annotate(" 1. $|z|=e^{-\pi/4}$",xy=(265,300),color='r',
             xytext=(-210, -50),
             textcoords='offset points', fontsize=16,
            arrowprops=dict(arrowstyle='->'))

plt.annotate(" 2. $|z|=e^{\pi/4}$",xy=(390,120),color='g',
             xytext=(-10, 50),
             textcoords='offset points', fontsize=16,
            arrowprops=dict(arrowstyle='->'))

plt.annotate(" 3. $  e^{-\pi/4} <= Im z <= e^{\pi/4}$",xy=(210,150),color='b',
             xytext=(-200, 50),
             textcoords='offset points', fontsize=16,
            arrowprops=dict(arrowstyle='->'))

plt.annotate(" 4. $  -e^{-\pi/4} <= Im z <= -e^{\pi/4}$",xy=(210,500),color='y',
             xytext=(-200, 50),
             textcoords='offset points', fontsize=16,
            arrowprops=dict(arrowstyle='->'))


plt.annotate(" $  -ie^{\pi/4}$",xy=(210,560),color='black',
             xytext=(-80, -30),
             textcoords='offset points', fontsize=16,
            arrowprops=dict(arrowstyle='->'))

plt.annotate(" $  -ie^{-\pi/4}$",xy=(210,360),color='black',
             xytext=(-80, -20),
             textcoords='offset points', fontsize=16,
            arrowprops=dict(arrowstyle='->'))

plt.annotate(" $  ie^{-\pi/4}$",xy=(210,245),color='black',
             xytext=(-80, -20),
             textcoords='offset points', fontsize=16,
            arrowprops=dict(arrowstyle='->'))

plt.annotate(" $  ie^{\pi/4}$",xy=(210,45),color='black',
             xytext=(-80, -20),
             textcoords='offset points', fontsize=16,
            arrowprops=dict(arrowstyle='->'))



ax =fig.add_subplot(1,2,2)
ax.set_title("$f(a)$")
ax.axis("off")
plt.imshow(Image.open("./week5-problem1-img2.png"))
plt.annotate(" 1. $x=-\pi/4 ,-\pi/2<y<\pi/2$",xy=(150,300),color='r',
             xytext=(-150, -90),
             textcoords='offset points', fontsize=16,
            arrowprops=dict(arrowstyle='->'))

plt.annotate(" 2. $x=\pi/4 ,-\pi/2<y<\pi/2$",xy=(265,300),color='g',
             xytext=(40, 0),
             textcoords='offset points', fontsize=16,
            arrowprops=dict(arrowstyle='->'))

plt.annotate(" 3. $-\pi/4 < x <\pi/4,y = \pi/2 $",xy=(250,85),color='b',
             xytext=(-0, 50),
             textcoords='offset points', fontsize=16,
            arrowprops=dict(arrowstyle='->'))

plt.annotate(" 4. $-\pi/4 < x <\pi/4,y = -\pi/2 $",xy=(250,325),color='y',
             xytext=(-100, -100),
             textcoords='offset points', fontsize=16,
            arrowprops=dict(arrowstyle='->'))

plt.annotate("$-\pi/4$",xy=(150,205),color='black',
             xytext=(-50, -50),
             textcoords='offset points', fontsize=16,
            arrowprops=dict(arrowstyle='->'))

plt.annotate("$\pi/4 $",xy=(265,205),color='black',
             xytext=(50, -50),
             textcoords='offset points', fontsize=16,
            arrowprops=dict(arrowstyle='->'))

plt.annotate("$\pi/2$",xy=(210,85),color='black',
             xytext=(-100, 10),
             textcoords='offset points', fontsize=16,
            arrowprops=dict(arrowstyle='->'))

plt.annotate("$-\pi/2$",xy=(210,325),color='black',
             xytext=(-50, -30),
             textcoords='offset points', fontsize=16,
            arrowprops=dict(arrowstyle='->'))

plt.show()

# %%
# plt.annotate("  $(e^{-\pi/4},\pi/2))$",xy=(194,185),color='r',
#              xytext=(-200, -50),
#              textcoords='offset points', fontsize=16,
#             arrowprops=dict(arrowstyle='->'))

# plt.annotate("$(e^{-\pi/4},-\pi/2))$",xy=(194,420),color='r',
#              xytext=(-200, -50),
#              textcoords='offset points', fontsize=16,
#             arrowprops=dict(arrowstyle='->'))

# plt.annotate("  $(e^{\pi/4},\pi/2))$",xy=(320,185),color='r',
#              xytext=(60, -50),
#              textcoords='offset points', fontsize=16,
#             arrowprops=dict(arrowstyle='->'))

# plt.annotate("$(e^{\pi/4},-\pi/2)$",xy=(320,420),color='r',
#              xytext=(60, -50),
#              textcoords='offset points', fontsize=16,
#             arrowprops=dict(arrowstyle='->'))

# %%
fig = plt.figure(figsize=(10,20))
ax =fig.add_subplot(1,1,1)
ax.set_title("$f(a)$")
ax.axis("off")
plt.imshow(Image.open("./week5-problem1-img2.png"))
plt.annotate(" 1. $|z|=e^{-\pi/4}$",xy=(150,300),color='b',
             xytext=(-150, -50),
             textcoords='offset points', fontsize=16,
            arrowprops=dict(arrowstyle='->'))

plt.annotate(" 2. $|z|=e^{\pi/4}$",xy=(265,300),color='b',
             xytext=(40, 0),
             textcoords='offset points', fontsize=16,
            arrowprops=dict(arrowstyle='->'))

plt.annotate(" 3. $  e^{-\pi/4} <= Im z <= e^{\pi/4}$",xy=(250,85),color='b',
             xytext=(-0, 50),
             textcoords='offset points', fontsize=16,
            arrowprops=dict(arrowstyle='->'))

plt.annotate(" 4. $  -e^{-\pi/4} <= Im z <= -e^{\pi/4}$",xy=(250,325),color='b',
             xytext=(-100, -100),
             textcoords='offset points', fontsize=16,
            arrowprops=dict(arrowstyle='->'))

plt.annotate("$-\pi/4$",xy=(150,205),color='black',
             xytext=(-50, -50),
             textcoords='offset points', fontsize=16,
            arrowprops=dict(arrowstyle='->'))

plt.annotate("$\pi/4 $",xy=(265,205),color='black',
             xytext=(50, -50),
             textcoords='offset points', fontsize=16,
            arrowprops=dict(arrowstyle='->'))

plt.annotate("$-\pi/2$",xy=(210,85),color='black',
             xytext=(-100, 10),
             textcoords='offset points', fontsize=16,
            arrowprops=dict(arrowstyle='->'))

plt.annotate("$\pi/2$",xy=(210,325),color='black',
             xytext=(-50, -30),
             textcoords='offset points', fontsize=16,
            arrowprops=dict(arrowstyle='->'))

plt.show()
